# %%
rec="본 예제는 빈칸으로 구분되어 있는 한 줄의 데이터를 빈칸을     구분하여 나누어 줌" #문자열 입력, 공백 5칸
item=rec.split(" ") #공백 단위로 리스트에 넣는다.

print("="*15) #구분선 출력
i=0 # 카운트용 변수 선언
for s in item: #리스트 안의 값을 s로 호출해서 사용하는 for문
    print(i,"==>", s) #i번째 s 를 출력한다.
    i+=1 #i 1증가
print("="*15) #구분선
# Out:
# ...
# 0 ==> 본
# 1 ==> 예제는
# 2 ==> 빈칸으로
# 3 ==> 구분되어
# 4 ==> 있는
# 5 ==> 한
# 6 ==> 줄의
# 7 ==> 데이터를
# 8 ==> 빈칸을
# 9 ==>
# 10 ==>
# 11 ==>
# 12 ==>
# 13 ==> 구분하여
# 14 ==> 나누어
# 15 ==> 줌
# ...

# %%
item="오징어땅콩" #품목
unit=1000 #단가
qty=10 #수량
tot=unit*qty #합계

print("case1") #기존의 방식
print("품목:",item," 단가:",unit,"원 수량:",qty,"개 합계:",tot,"원")

print("case2") #하나의 긴 문자열을 만들어 출력하면 공백없이 출력이 가능
print("품목:"+item+" 단가:"+str(unit)+"원 수량:"+str(qty)+"개 합계:"+str(tot)+"원")

print("case3") #포멧에 맞게 출력문자를 출력한다.
print("품목:%s 단가:%d원 수량:%d개 합계:%d원"%(item,unit,qty,tot))

print("case4") #포메팅하여 값을 형식에 맞게 출력
print("품목:%-10s 단가:%05d원 수량:0x%02x개 합계:%10.3f원"%(item,unit,qty,tot))
# Out:
# case1
# 품목: 오징어땅콩  단가: 1000 원 수량: 10 개 합계: 10000 원
# case2
# 품목:오징어땅콩 단가:1000원 수량:10개 합계:10000원
# case3
# 품목:오징어땅콩 단가:1000원 수량:10개 합계:10000원
# case4
# 품목:오징어땅콩      단가:01000원 수량:0x0a개 합계: 10000.000원

# %%
item="땅콩" #문자형 자료
unit=1000 #숫자형 자료

print("[%5d][%-5d][%05d]"%(unit,unit,unit)) #5칸 오른쪽 정렬, 5칸 왼쪽 정렬, 5칸 오른쪽 정렬(빈칸은 0)
print("[%5s][%-5s][%05s]"%(item,item,item)) #5칸 오른쪽 정렬, 5칸 왼쪽 정렬, 5칸 오른쪽 정렬
print("[%d]=[%x][%#x][%o]"%(unit,unit,unit,unit))#정수형 출력, 16진수 출력, 0xb 와 같은 형식으로 표현, 8진수 출력, 
print("[%5d%%]"%unit) #5칸 왼쪽정렬 + %출력

#한글은 1byte로 자르면 에러
a="abcd" #문자형 자료 str
print("[%c][%c][%c]"%(a[0],a[1],a[2])) #%c는 문자 자료형 출력포멧 a b c 출력
# Out:
# [ 1000][1000 ][01000]
# [   땅콩][땅콩   ][   땅콩]
# [1000]=[3e8][0x3e8][1750]
# [ 1000%]
# [a][b][c]

# %%
import locale #locale라이브러리를 임포트 함, 설치는 필요없음
locale.setlocale(locale.LC_ALL, "") # 시스템 기본 로케일 사용
n = -1234567890.123 #숫자 입력
s = locale.format_string("%.3f", n, 1) #숫자에 대해 3번째 마다 콤마를 찍어준다.
print(s)
# Out:
# -1,234,567,890.123

# %%
import locale #라이브러리 임포트
locale.setlocale(locale.LC_ALL, "")  #시스템 기본 로케일 사용

myWon=1000000  #숫자형 자료 지정, 100만원
moneyEx=1010.12 #달러환율
commission_rate=0.002  #은행 수수료
a = moneyEx + moneyEx*commission_rate #1달러당 환율금액, 수수료의 합
usd = int (myWon /a) #소수점으로 나오는 부분 버림

remain = int(myWon - usd * a) #거스름 돈 계산
  
commission = usd * moneyEx * commission_rate #환전 수수료총액 계산
   
if(commission != float(int(commission))) : #수수료가 소수점 이하가 있다면
    commission = int(commission) +1 # 올림해라
else:
    commission = int(commission) #수수료가 소수점 이하가 없다면 정수형으로 바꿔라
#총액 출력 구간, 포멧팅에 맞게 값을 출력한다.
print("***************************************************")
print("총금액: %s원 \t달러환율: $%s"%( \
    locale.format_string("%12d", myWon, 1), \
    locale.format_string("%-12d", moneyEx, 1)) )
#거스름돈 출력 구간, 포멧팅에 맞게 값을 출력한다.
print("지급달러: $%s"% locale.format_string("%-12d", usd, 1))
print("거스름돈: %s원 \t은행수수료: %s원"%( \
    locale.format_string("%6d", remain, 1), \
    locale.format_string("%6d", commission, 1)) )
print("***************************************************")
# Out:
# ***************************************************
# 총금액:    1,000,000원 	달러환율: $1,010
# 지급달러: $988
# 거스름돈:      5원 	은행수수료:  1,996원
# ***************************************************

# %%
def titleprint(): #상단부 출력 함수
    print("="*50) #구분선 출력
    print("이름\t국어\t영어\t수학\t총점\t평균") #항목 출력
    print("="*50) #구분선 출력
              
def itemprint(name,kor,eng,mat): #4개의 인자를 받는 함수, 성적부분 출력
    print(name,"\t",kor,"\t",eng,"\t",mat,"\t",kor+eng+mat,"\t",(kor+eng+mat)//3) #이름,성적,총점, 평균
              
def tailprint(): #하단부 출력(성적 집계 및 평균)
    totkor=0 #숫자형 변수 선언, 국어 성적 합 
    toteng=0 #숫자형 변수 선언, 영어 성적 합
    totmat=0 #숫자형 변수 선언, 수학 성적 합
    for one_student in score: #성적 리스트에서 값을 추출하는 for문
        totkor+=one_student[kor] 
        toteng+=one_student[eng]
        totmat+=one_student[mat]
    print("="*50) #구분선 출력
    #총점, 평균을 포멧에 맞게 출력한다.
    print("반총점\t",totkor,"\t",toteng,"\t",totmat,"\t"\
        ,(totkor+toteng+totmat),"\t",(totkor+toteng+totmat)/3//9)
    print("="*50) #구분선 출력
              
#데이터 리스트
dili_score=["나연,100,90,100",
    "정연,90,90,100",
    "모모,80,70,90",
    "사나,90,90,80",
    "지효,100,80,80",
    "미나,50,90,90",
    "다현,80,60,100",
    "채영,70,80,90",
    "쯔위,100,90,90"]

score=[] #추출한 데이터를 담을 리스트 선언
for one_rec in dili_score: #2차원리스트에서 값을 하나씩 대입하는 for문
    one_score=one_rec.split(",") # 콤마 단위로 잘라서 리스트에 대입
    one_score[1]=int(one_score[1]) #국어점수 숫자형 변환
    one_score[2]=int(one_score[2]) #영어점수 숫자형 변환
    one_score[3]=int(one_score[3]) #수학점수 숫자형 변환
    score.append(one_score.copy()) # copy에 주의할 것..값 복사

# 각 변수들의 리스트에서의 위치
name=0;kor=1;eng=2;mat=3

#위에서 선언한 함수들을 실행한다.
titleprint()
for one_student in score:
    itemprint(one_student[name],one_student[kor],one_student[eng],one_student[mat])
tailprint()
# Out:
# ...
# 이름	국어	영어	수학	총점	평균
# ...
# 나연 	 100 	 90 	 100 	 290 	 96
# 정연 	 90 	 90 	 100 	 280 	 93
# 모모 	 80 	 70 	 90 	 240 	 80
# 사나 	 90 	 90 	 80 	 260 	 86
# 지효 	 100 	 80 	 80 	 260 	 86
# 미나 	 50 	 90 	 90 	 230 	 76
# 다현 	 80 	 60 	 100 	 240 	 80
# 채영 	 70 	 80 	 90 	 240 	 80
# 쯔위 	 100 	 90 	 90 	 280 	 93
# ...
# 반총점	 760 	 740 	 820 	 2320 	 85.0
# ...

# %%
#데이터 입력
dili_score=["나연,100,90,100",
    "정연,90,90,100",
    "모모,80,70,90",
    "사나,90,90,80",
    "지효,100,80,80",
    "미나,50,90,90",
    "다현,80,60,100",
    "채영,70,80,90",
    "쯔위,100,90,90"]

score=[] #성적 배열 선언, 데이터 추출할 때 사용
for one_rec in dili_score: #자료의 값들을 돌리는 for문 작성
    one_score=one_rec.split(",") #콤마 단위로 받아온 데이터를 잘라서 넣는다.
    one_score[1]=int(one_score[1]) #국어점수 숫자형 변환
    one_score[2]=int(one_score[2]) #영어점수 숫자형 변환
    one_score[3]=int(one_score[3]) #수학점수 숫자형 변환
    score.append(one_score.copy()) # copy에 주의할 것..값 복사

print(score)
# Out:
# [['나연', 100, 90, 100], ['정연', 90, 90, 100], ['모모', 80, 70, 90], ['사나', 90, 90, 80], ['지효', 100, 80, 80], ['미나', 50, 90, 90], ['다현', 80, 60, 100], ['채영', 70, 80, 90], ['쯔위', 100, 90, 90]]

# %%
import math #math 모듈을 import 한다
math.sin(0) #math 모듈에 sin함수를 하용한다.
# Out:
# 0.0

# %%
math.pi #math 모듈의 pi 를 사용한다.
# Out:
# 3.141592653589793

# %%
math.sin(math.pi/2.0) #sin(90도)를 의미한다.
# Out:
# 1.0

# %%
from math import sin #math 모듈의 함수 선언
sin(3.141592/2)
# Out:
# 0.9999999999999466

# %%
from math import sin, pi #여러 함수 사용 가능
sin(pi/2.0)
# Out:
# 1.0

# %%
import math as m #math 를 m 으로 선언해서 사용
m.sin(m.pi/2.0)
# Out:
# 1.0

# %%
import math
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     ceil(x, /)
# ...

# %%
from math import sin,pi #math 모듈의 sin과pi 호출

for i in range(360): #0부터 360전까지 도는 for문 작성
    sin_value=sin(i*pi/180) #i에 따른 sin값 저장
    space_value=int( (1+sin_value)*50) #sin값에 따라 빈칸을 생성하기 위해 선언한 변수
    print(" "*space_value, end="") #공간 수 만큼 여백을 생성한다.
    print("[%f]"%sin_value) #값을 실수형으로 출력한다.
# Out:
#                                                   [0.000000]
#                                                   [0.017452]
#                                                    [0.034899]
#                                                     [0.052336]
#                                                      [0.069756]
#                                                       [0.087156]
#                                                        [0.104528]
#                                                         [0.121869]
#                                                         [0.139173]
#                                                          [0.156434]
#                                                           [0.173648]
#                                                            [0.190809]
#                                                             [0.207912]
#                                                              [0.224951]
# ...

# %%
from math import sin,pi #math 에서 sin pi 함수 호출
import matplotlib.pyplot as plt #matplotlib 선언 plt 으로

graph_value=[] #리스트 선언,빈 리스트를 만들어야 append가능
for i in range(360): #0부터 360전까지 도는 for문 작성
    graph_value.append(sin(i*pi/180)) #sin값을 하나씩 리스트에 넣음

plt.plot(graph_value) #해당 리스트를 그래프 함수에 보냄
plt.show() #그래프를 보여준다.

# %%
import statistics as s #해당 모듈을 s로 선언
a=[100,95,25,33,45,90,100,35,25] #리스트에 값 입력
s.mean(a) #평균
# Out:
# 60.888888888888886

# %%
s.stdev(a) #표준편차
# Out:
# 34.18129768032675

# %%
s.variance(a) #분산
# Out:
# 1168.361111111111

# %%
import statistics as s #해당 모듈을 s로 선언
s.harmonic_mean([120,80]) #두 수의 평균을 구한다.
# Out:
# 96.0

# %%
import time as t #time 모듈 호출
a=t.time(); # 현재 시간을 a에 입력
a #현재시간을 구함
# Out:
# 1651456079.2355433

# %%
t.ctime(a) #초단위로 표시된 시간을 문자형으로 표현
# Out:
# 'Mon May  2 10:47:59 2022'

# %%
t.ctime(0) #우리나라 기준으로 time=0의 경우 1970년1월1일 오전9시 정각이다
# Out:
# 'Thu Jan  1 09:00:00 1970'

# %%
import time as t # time 모듈을 t 로 호출
a = t.localtime() #시간 요소를 구조체로 반환
a # 출력
# Out:
# time.struct_time(tm_year=2022, tm_mon=5, tm_mday=2, tm_hour=10, tm_min=50, tm_sec=30, tm_wday=0, tm_yday=122, tm_isdst=0)

# %%
print("%d년 %d월 %d일 %02d시 %02d분 %02d초"%(a.tm_year,a.tm_mon,a.tm_mday,a.tm_hour,a.tm_min,a.tm_sec))
# Out:
# 2022년 5월 2일 10시 50분 30초

# %%
import datetime as t #datetime 을 t 로 선언
a=t.datetime.now() #now함수 입력
print("%d년 %d월 %d일 %02d시 %02d분 %02d초"%(a.year,a.month,a.day,a.hour,a.minute,a.second))
# Out:
# 2022년 5월 2일 10시 53분 11초

# %%
import time as t #time 모듈을 t로 선언

start = t.time() #시작할 때, time 함수 실행
for i in range(10000): #for문이 실행되는 시간을 구하려고 선언
    pass
end = t.time() #끝날 때, time 함수 실행

print("%f 초 동안 실행함"%(end-start))
# Out:
# 0.000998 초 동안 실행함

# %%
import time as t #time 모듈을 t로 선언

for i in range(10): #0부터 9까지 도는 for문 작성
    print(t.ctime()) #ctime 함수를 실행하고 아래 코드로 인해 3초 쉰다.
    t.sleep(3) #3초 쉬고 다시 실행
# Out:
# Mon May  2 10:56:55 2022
# Mon May  2 10:56:58 2022
# Mon May  2 10:57:01 2022
# Mon May  2 10:57:05 2022
# Mon May  2 10:57:08 2022
# Mon May  2 10:57:11 2022
# Mon May  2 10:57:14 2022
# Mon May  2 10:57:17 2022
# Mon May  2 10:57:20 2022
# Mon May  2 10:57:23 2022

# %%
import random as r #random 모듈을 r 로 선언
import matplotlib.pyplot as plt #matplotlib을 plt 으로 선언

score=[] #점수를 담을 리스트 선언
for i in range(100): #i에 0부터 99까지 입력하는 for문 작성
    score.append(r.randrange(0,100)) #리스트에 random모듈의 randrange 사용

plt.plot(score) #만들어진 스르트의 그래프를 그란다.
plt.show() #그래프를 보여준다.

# %%
import sys #sys 모듈을 호출한다
sys.version #파이썬의 버전을 확인한다
# Out:
# '3.10.4 (tags/v3.10.4:9d38120, Mar 23 2022, 23:13:41) [MSC v.1929 64 bit (AMD64)]'

# %%
sys.platform #파이썬 설치 플랫폼
# Out:
# 'win32'

# %%
sys.getwindowsversion() #설치된 윈도우의 버전
# Out:
# sys.getwindowsversion(major=10, minor=0, build=19044, platform=2, service_pack='')

# %%
import os #os 모듈을 호출
os.getcwd() # 실행하고 있는 위치
# Out:
# 'C:\\jupyter'

# %%
os.system("calc") #계산기 실행
# Out:
# 0

# %%
os.system( "IDLE" ) #IDLE실행,실행안됨 path가 다름, 1리턴
# Out:
# 1

# %%
os.system("python") #파이썬 실행 실행된 상태에서 기다림
# Out:
# 0

# %%
os.system("shutdown -f -t 10") #이 명령 수행전 모든 윈도우 프로그램을 정리할 것
# Out:
# 1

# %%
from urllib.request import urlopen # urllib에서 urlopen 호출
#학원 사이트를 urlopne을 사용해서 열고 response 라고 명명
with urlopen('http://www.kopo.ac.kr/') as response:
    for line in response: #홈페이지를 연 것을 line 에 하나씩 넣는 for문 작성
        line = line.decode('utf-8') # 한글 처리
        if "폴리텍" in line: #받아온 line 중 폴리텍이 있으면 출력한다.
            print(line)
# Out:
# <meta name="author" content="폴리텍대학" />
#
# <meta name="description" content="폴리텍대학 홈페이지입니다." />
#
# <meta name="keywords" content="폴리텍대학" />
#
# <title>학교법인한국폴리텍</title>
#
# 	<a class="nav-skip__item" href="#pg-div">학교법인한국폴리텍본문 바로가기</a><br/>
#
# 	<a class="nav-skip__item" href="#kopoMenu">학교법인한국폴리텍주메뉴 바로가기</a>
#
# 			<a href ="javascript:showAllCampus();" title="폴리텍대학 캠퍼스 목록 표시">전국 캠퍼스 안내</a>
#
# 				<h3>한국폴리텍대학 전국 캠퍼스 안내</h3>
#
# 			<img class="all_campus_map" alt="한국폴리텍대학 전국 캠퍼스 지도" src="/images/kopo/all_campus_map2.png"/>
#
# 		<a href="#" class="all_campus_close" onclick="showAllCampus(); return false;"><img alt="한국폴리텍대학 전국 캠퍼스 바로가기 닫기" src="/images/kopo/all_cam_close.png"/></a>
#
# 			<img src="/assets2021/img/logo_header_pc.png" alt="한국폴리텍대학 ">
#
# 							폴리텍대학 소개</span></a><div class="depth-2"><div class="container">
#
# 							폴리텍대학 소개</span></a></div>
#
# 							폴리텍 역사</span></a></li>
#
# 							폴리텍대학 소식</span></a></div>
#
# 							폴리텍대학 홍보</span></a></div>
#
# ...

# %%
f=0 #변수 선언
try: #try - catch - finally 문 실행
    f=open("LICENSE.txt","rt") #LICENSE.txt 명의 텍스트 파일 읽기모드로 열기
    while True: #무한 루프
        r=f.readline() #라인이 없어질때까지 메세지 출력
        if not r:
            break
        print(r) 
except FileNotFoundError: #파일이 없을경우 메세지 출력
    print("파일없음")
finally: #다 끝나고 나면 메세지 출력
    if(f): f.close()
    print("프로그램 끝")
# Out:
# 파일없음
# 프로그램 끝

# %%
f=0 #빈 변수 선언
f=open("score.txt","wt") #score.txt로 파일명 지정, 쓰기 + 텍스트 파일형
for i in range(100): #0부터 99까지 i에 입력하는 for문 작성
    one_person="홍길동"+str(i)+","+str(r.randrange(0,100))+","+str(r.randrange(0,100)) +","+str(r.randrange(0,100))+"\n"
    #홍길동+번호, 범위랜덤함수로 성적 무작위 입력
    f.write(one_person) #한 줄씩 쓴다
    print(one_person) #값 출력
f.close() #파일 작성 종료
# Out:
# 홍길동0,99,93,72
#
# 홍길동1,42,57,9
#
# 홍길동2,6,87,28
#
# 홍길동3,83,39,77
#
# 홍길동4,63,32,69
#
# 홍길동5,43,89,83
#
# 홍길동6,89,58,13
#
# 홍길동7,45,16,10
#
# 홍길동8,0,1,96
#
# 홍길동9,8,29,48
#
# 홍길동10,58,14,58
#
# 홍길동11,8,82,44
#
# 홍길동12,98,7,0
#
# 홍길동13,97,46,91
#
# 홍길동14,93,64,29
#
# 홍길동15,83,7,93
#
# 홍길동16,87,55,71
#
# 홍길동17,45,43,17
#
# 홍길동18,47,88,10
#
# 홍길동19,3,85,22
#
# 홍길동20,39,38,75
#
# 홍길동21,5,0,10
#
# 홍길동22,82,46,11
#
# 홍길동23,9,40,61
#
# 홍길동24,15,25,95
#
# 홍길동25,29,51,45
#
# 홍길동26,4,38,74
#
# 홍길동27,16,44,30
#
# 홍길동28,29,26,19
#
# 홍길동29,88,64,38
#
# 홍길동30,31,94,51
#
# 홍길동31,41,4,57
#
# 홍길동32,33,84,0
#
# 홍길동33,43,24,11
#
# 홍길동34,61,76,83
#
# 홍길동35,54,64,49
#
# 홍길동36,72,93,38
#
# 홍길동37,34,68,46
#
# 홍길동38,65,61,0
#
# 홍길동39,69,41,95
#
# 홍길동40,13,71,95
#
# 홍길동41,21,87,74
#
# 홍길동42,41,89,66
#
# 홍길동43,87,80,86
#
# 홍길동44,71,9,29
#
# 홍길동45,27,7,31
#
# 홍길동46,9,97,68
#
# 홍길동47,41,5,56
#
# 홍길동48,98,47,94
#
# 홍길동49,49,58,45
#
# 홍길동50,89,32,13
#
# 홍길동51,71,39,77
#
# 홍길동52,69,26,68
#
# 홍길동53,63,59,6
#
# ...

# %%
f=0 # 빈 변수 선언
f=open("score.txt","rt") #위에서 생성한 파일 읽어오기, 읽기+텍스트파일
while True: #무한루프
    one_person=f.readline() #한 줄씩 읽는다
    if not one_person:  #읽을 내용이 없으면 루프탈출
        break 
    one_person=one_person.replace("\n","") #줄 바꿈문자 없애기
    item=one_person.split(",") #콤마 구분자로 짜르기
    print("="*15) #구분선 출력
    print("이름: ", item[0]) #읽어온 파일에서 이름 출력
    print("국어: ", item[1]) #읽어온 파일에서 국어 출력
    print("영어: ", item[2]) #읽어온 파일에서 영어 출력
    print("수학: ", item[3]) #읽어온 파일에서 수학 출력
    print("="*15) #구분선 출력
f.close() #파일 읽기 종료
# Out:
# ...
# 이름:  홍길동0
# 국어:  99
# 영어:  93
# 수학:  72
# ...
# 이름:  홍길동1
# 국어:  42
# 영어:  57
# 수학:  9
# ...
# 이름:  홍길동2
# 국어:  6
# 영어:  87
# 수학:  28
# ...
# 이름:  홍길동3
# 국어:  83
# 영어:  39
# 수학:  77
# ...
# 이름:  홍길동4
# 국어:  63
# 영어:  32
# 수학:  69
# ...
# 이름:  홍길동5
# 국어:  43
# 영어:  89
# 수학:  83
# ...
# 이름:  홍길동6
# 국어:  89
# 영어:  58
# 수학:  13
# ...
# 이름:  홍길동7
# 국어:  45
# 영어:  16
# 수학:  10
# ...
# 이름:  홍길동8
# 국어:  0
# 영어:  1
# 수학:  96
# ...
# 이름:  홍길동9
# 국어:  8
# 영어:  29
# 수학:  48
# ...
# 이름:  홍길동10
# 국어:  58
# 영어:  14
# 수학:  58
# ...
# 이름:  홍길동11
# 국어:  8
# 영어:  82
# 수학:  44
# ...
# 이름:  홍길동12
# 국어:  98
# 영어:  7
# 수학:  0
# ...
# 이름:  홍길동13
# 국어:  97
# 영어:  46
# 수학:  91
# ...
# 이름:  홍길동14
# 국어:  93
# 영어:  64
# 수학:  29
# ...
# 이름:  홍길동15
# 국어:  83
# 영어:  7
# 수학:  93
# ...
# 이름:  홍길동16
# 국어:  87
# 영어:  55
# 수학:  71
# ...
# 이름:  홍길동17
# 국어:  45
# 영어:  43
# 수학:  17
# ...
# 이름:  홍길동18
# 국어:  47
# 영어:  88
# 수학:  10
# ...
# 이름:  홍길동19
# 국어:  3
# 영어:  85
# 수학:  22
# ...
# 이름:  홍길동20
# 국어:  39
# 영어:  38
# 수학:  75
# ...
# 이름:  홍길동21
# 국어:  5
# 영어:  0
# 수학:  10
# ...
# 이름:  홍길동22
# 국어:  82
# 영어:  46
# 수학:  11
# ...
# 이름:  홍길동23
# 국어:  9
# 영어:  40
# ...

# %%
import sqlite3 as s #sqlite3를 s로 선언
con=s.connect("my01.db") #DB연결, 현 소스파일의 디렉토리
cursor = con.cursor() #데이터베이스 사용공간을 만든다.

#table 삭제
cursor.execute("drop table examtable;") 
con.commit()

#table 생성
cursor.execute(" \ 
create table examtable( \
    name varchar(20),\
    studentid int not null primary key,\
    kor int,\
    eng int,\
    mat int) \
        ")

con.commit() #버퍼에 처리된 내용을 기록 commit
cursor.close()
con.close()
# Out:
#   Input In [69]
#     cursor.execute(" \
#                    ^
# SyntaxError: unterminated string literal (detected at line 10)

# %%
import sqlite3 as s
con=s.connect("my01.db")
cursor = con.cursor()

cursor.execute("insert into examtable (name, studentid, kor, eng, mat) values (\"나연\", 20990001, 95, 100, 95);") 
#테이블내 레코드 삽입
cursor.execute("insert into examtable (name, studentid, kor, eng, mat) values (\"정연\", 20990002, 90, 90, 85);")
cursor.execute("insert into examtable (name, studentid, kor, eng, mat) values (\"모모\", 20990003, 95, 95, 75);")
cursor.execute("insert into examtable (name, studentid, kor, eng, mat) values (\"사나\", 20990004, 85, 90, 90);")
cursor.execute("insert into examtable (name, studentid, kor, eng, mat) values (\"지효\", 20990005, 100, 90, 85);")
cursor.execute("insert into examtable (name, studentid, kor, eng, mat) values (\"미나\", 20990006, 90, 80, 90);")
cursor.execute("insert into examtable (name, studentid, kor, eng, mat) values (\"다현\", 20990007, 75, 90, 100);")
cursor.execute("insert into examtable (name, studentid, kor, eng, mat) values (\"채영\", 20990008, 95, 70, 90);")
cursor.execute("insert into examtable (name, studentid, kor, eng, mat) values (\"쯔위\", 20990009, 85, 90, 90);")

con.commit()
cursor.close()
con.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [70], in <cell line: 5>()
#       2 con=s.connect("my01.db")
#       3 cursor = con.cursor()
# ----> 5 cursor.execute("insert into examtable (name, studentid, kor, eng, mat) values (\"나연\", 20990001, 95, 100, 95);")
#       6 #테이블내 레코드 삽입
#       7 cursor.execute("insert into examtable (name, studentid, kor, eng, mat) values (\"정연\", 20990002, 90, 90, 85);")
#
# OperationalError: no such table: examtable

# %%
import sqlite3 as s #sqlite3 를 s로 호출
con=s.connect("my01.db") #my01.db 와 연결
cursor = con.cursor() #con의 cursor함수를 cursor 함수를 저장

con.commit() #commit 실행
#create 명령 실행, examtable의 변수 및 크기 지정
cursor.execute("create table examtable(name varchar(20), studentid int not null primary key, kor int, eng int, mat int)")
con.commit() #버퍼에 처리된 내용을 기록 commit
cursor.close() #커서 종료
con.close() #커넥트 종료

# %%
import sqlite3 as s #sqlite3 를 s로 호출
con=s.connect("my01.db") #my01.db 와 연결
cursor = con.cursor() #con의 cursor함수를 cursor 함수를 저장
cursor.execute("drop table examtable;") #table 삭제 실행, 위에서 만든 테이블 삭제
con.commit() #commit 실행
#create 명령 실행, examtable의 변수 및 크기 지정
cursor.execute("create table examtable(name varchar(20), studentid int not null primary key, kor int, eng int, mat int)")
con.commit() #버퍼에 처리된 내용을 기록 commit
cursor.close() #커서 종료
con.close() #커넥트 종료

# %%
import sqlite3 as s #sqlite3 를 s로 호출
con=s.connect("my01.db") #my01.db 와 연결
cursor = con.cursor() #con의 cursor함수를 cursor 함수를 저장

#테이블내에 트와이스의 이름, 학번, 성적 정보 입력
cursor.execute("insert into examtable (name, studentid, kor, eng, mat) values (\"나연\", 20990001, 95, 100, 95);") 
cursor.execute("insert into examtable (name, studentid, kor, eng, mat) values (\"정연\", 20990002, 90, 90, 85);")
cursor.execute("insert into examtable (name, studentid, kor, eng, mat) values (\"모모\", 20990003, 95, 95, 75);")
cursor.execute("insert into examtable (name, studentid, kor, eng, mat) values (\"사나\", 20990004, 85, 90, 90);")
cursor.execute("insert into examtable (name, studentid, kor, eng, mat) values (\"지효\", 20990005, 100, 90, 85);")
cursor.execute("insert into examtable (name, studentid, kor, eng, mat) values (\"미나\", 20990006, 90, 80, 90);")
cursor.execute("insert into examtable (name, studentid, kor, eng, mat) values (\"다현\", 20990007, 75, 90, 100);")
cursor.execute("insert into examtable (name, studentid, kor, eng, mat) values (\"채영\", 20990008, 95, 70, 90);")
cursor.execute("insert into examtable (name, studentid, kor, eng, mat) values (\"쯔위\", 20990009, 85, 90, 90);")

con.commit() #버퍼에 처리된 내용을 기록 commit
cursor.close() #커서 종료
con.close() #커넥트 종료

# %%
import sqlite3 as s #sqlite3 를 s로 호출
con=s.connect("my01.db") #my01.db 와 연결
cursor = con.cursor() #con의 cursor함수를 cursor 함수를 저장
# 테이블의 모든 내용 출력하는 명령 실행
cursor.execute("select * from examtable")

one_rec=cursor.fetchall() #해당 데이터를 전부 가져옴

for field in one_rec: #해당 데이터를 반복문을 통해 하나씩 처리
    kor=field[2]
    eng=field[3]
    mat=field[4]
    print("이름:%s 학번:%s 국어:%3d 영어:%3d 수학:%3d 총점:%3d 평균:%3d"%(field[0],field[1],kor,eng,mat,kor+eng+mat,int((kor+eng+mat)/3)))

cursor.close() #커서 종료
con.close() #커넥트 종료
# Out:
# 이름:나연 학번:20990001 국어: 95 영어:100 수학: 95 총점:290 평균: 96
# 이름:정연 학번:20990002 국어: 90 영어: 90 수학: 85 총점:265 평균: 88
# 이름:모모 학번:20990003 국어: 95 영어: 95 수학: 75 총점:265 평균: 88
# 이름:사나 학번:20990004 국어: 85 영어: 90 수학: 90 총점:265 평균: 88
# 이름:지효 학번:20990005 국어:100 영어: 90 수학: 85 총점:275 평균: 91
# 이름:미나 학번:20990006 국어: 90 영어: 80 수학: 90 총점:260 평균: 86
# 이름:다현 학번:20990007 국어: 75 영어: 90 수학:100 총점:265 평균: 88
# 이름:채영 학번:20990008 국어: 95 영어: 70 수학: 90 총점:255 평균: 85
# 이름:쯔위 학번:20990009 국어: 85 영어: 90 수학: 90 총점:265 평균: 88
